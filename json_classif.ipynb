# %% [markdown]
# # handle test and train data

# %%
import json

def flatten_json(json_obj, prefix=''):
    """
    Recursively flattens the JSON structure into a flat dictionary of key-value pairs.

    :param json_obj: The JSON object (dict, list, or primitive).
    :param prefix: The current prefix to build the path.
    :return: A flat dictionary with keys as the path to the original value.
    """
    items = []
    if isinstance(json_obj, dict):
        for key, value in json_obj.items():
            new_key = f"{prefix}.{key}" if prefix else key
            items.extend(flatten_json(value, new_key).items())
    elif isinstance(json_obj, list):
        for index, value in enumerate(json_obj):
            new_key = f"{prefix}[{index}]"
            items.extend(flatten_json(value, new_key).items())
    else:
        items.append((prefix, json_obj))
    return dict(items)

def extract_paths(json_obj, current_path=""):
    paths = []

    if isinstance(json_obj, dict):
        for key, value in json_obj.items():
            new_path = f"{current_path}.{key}" if current_path else key
            paths.extend(extract_paths(value, new_path))

    elif isinstance(json_obj, list):
        for index, value in enumerate(json_obj):
            new_path = f"{current_path}[{index}]"
            paths.extend(extract_paths(value, new_path))

    else:
        paths.append(current_path)

    return paths

# Example usage
if __name__ == "__main__":
    # Sample JSON object
    json_data = {
        "user": {
            "profile": {
                "name": "John Doe",
                "age": 30
            },
            "settings": {
                "theme": "dark"
            }
        },
        "posts": [
            {"id": 1, "content": "Post 1"},
            {"id": 2, "content": "Post 2"}
        ]
    }

    # Extract paths from the JSON
    semantic_paths = extract_paths(json_data)
    fl = flatten_json(json_data)

    print(fl)

    # Print the paths
    for path in semantic_paths:
        print(path)
# Out:
# {'user.profile.name': 'John Doe', 'user.profile.age': 30, 'user.settings.theme': 'dark', 'posts[0].id': 1, 'posts[0].content': 'Post 1', 'posts[1].id': 2, 'posts[1].content': 'Post 2'}
# user.profile.name
# user.profile.age
# user.settings.theme
# posts[0].id
# posts[0].content
# posts[1].id
# posts[1].content

# %%
import json


class Group:
    def __init__(self, group_id, name, key_words, samples):
        self.id = group_id
        self.name = name
        self.key_words = key_words
        self.samples = samples
        self.vectorized_samples = None

    def __repr__(self):
        return f"Group(id={self.id}, name={self.name}, samples={self.samples})"


def parse_labels(label_file: str) -> list[Group]:
    with open(label_file, 'r') as f:
        data = json.load(f)

    groups = [
        Group(
            group_id=label["id"],
            name=label["name"],
            key_words=label.get("key_words", []),
            samples=label.get("samples", [])
        )
        for label in data[0].get("labels", [])
    ]
    return groups

# %%
groups = parse_labels('labels.json')

# %%
print(groups)
# Out:
# [Group(id=0, name=battery_voltage, samples=['batV', 'batt_v', 'batt_mV', 'bat_mV', 'Bat_V', 'Bat_mV', 'batteryVoltage', 'vbat', 'vBat', 'batVoltage', 'battery_vol', 'battVoltage', 'Vbat', 'BatV', 'BAT_V', 'batteryLevel', 'battery_level', 'batLevel', '[03] Voltage Battery/Input [V]']), Group(id=1, name=battery_voltage_mean_24h, samples=['battery_voltage_mean_24h']), Group(id=2, name=battery_percent, samples=['batteryPerc', 'battPerc', 'battery_capacity_percentage', 'batteryCapacity', 'battery_health', 'Battery']), Group(id=3, name=battery_status, samples=['Bat_status']), Group(id=4, name=outdoor_temperature, samples=['temperatures', 'temperature', 'temp_SOIL', 'TEMP_SOIL', 'air_temperature', 'Air Temperature', 'ambientTemp', 'ambient_temperature', 'Ambient_Temperature', 'barometer_temperature', 'temperature_head', 'head_temperature', 'surface_temperature', 'tempC_DS18B20', 'TempC_DS18B20', 'tempC_SHT', 'TempC_SHT', 'TempPH', 'TempNTU', 'SoildTemp5TE', 'TempLDO', 'temp_Channel', 'Temp_Channel', 'Leaf_Temperature', 'Flow_Temperature', 'soil_temperature', 'temperature_pt1000', 'soil_temperature_at_depth', 'waterTemp', 'extThermistorTemperature', 'TH_Sensor_Temperature', 'bleTemp', 'sensorTemperature']), Group(id=5, name=internal_temperature, samples=['mcu_temperature', 'sensor_temperature_internal', 'temperatureBoard', 'onboard_temperature', 'Lidar_temp', 'cpu_temp', 'cputemp']), Group(id=6, name=temperature_high_limit, samples=['TemperatureLimitHigh', 'tempMax']), Group(id=7, name=external_temperature, samples=['TempC_DS', 'tempC_DS', 'Ext_TempC_SHT']), Group(id=8, name=temperature_high_limit, samples=['TemperatureLimitHigh', 'tempMax']), Group(id=9, name=temperature_low_limit, samples=['TemperatureLimitLow', 'tempMin']), Group(id=10, name=temperature_high_limit_is_exceeded, samples=['tempAlarmLimitHigh', 'HighTempAlarm']), Group(id=11, name=temperature_low_limit_is_exceeded, samples=['tempAlarmLimitLow']), Group(id=12, name=temperature_alarm_is_active, samples=['TemperatureAlertsEnabled', 'temperatureAlertActive', 'tempAlarmsEnabled']), Group(id=13, name=temperature_is_changed, samples=['temperatureChanged', 'tempHumidChanged', 'TempChange']), Group(id=14, name=target_temperature, samples=['targetTemperature']), Group(id=15, name=leak_water, samples=['leak', 'leakage_status', 'waterleak', 'WaterLeak', 'WATER_LEAK_STATUS', 'water']), Group(id=16, name=leak_time, samples=['WATER_LEAK_TIMES']), Group(id=17, name=leak_location, samples=['WaterLeakLocation']), Group(id=18, name=leak_alarm, samples=['TankLeakAlarm']), Group(id=19, name=voltage, samples=['voltage', 'Voltage', 'input_voltage', 'capacitor_voltage', 'rms_voltage', 'voltage-transformer primary', 'voltage-transformer secondary', 'Volt', 'Vol', 'Supply_Voltage', 'Storage_Voltage', 'SystemVoltage', 'AVI_V']), Group(id=20, name=current, samples=['IDC_intput_mA', 'idc_intput_mA', 'ACI_mA', 'current', 'Current']), Group(id=21, name=current_is_change, samples=['IDC_intput_mA', 'idc_intput_mA', 'ACI_mA', 'current', 'Current']), Group(id=22, name=window_open, samples=['openWindow', 'window_open', 'window_detection']), Group(id=23, name=window_close, samples=[]), Group(id=24, name=door_open, samples=['Door_status', 'door_status', 'DOOR_OPEN_STATUS']), Group(id=25, name=door_close, samples=['closed']), Group(id=26, name=duration_door_open, samples=['LAST_DOOR_OPEN_DURATION']), Group(id=27, name=count_door_openings, samples=['DOOR_OPEN_TIMES']), Group(id=28, name=active_energy, samples=['Active Energy Import T']), Group(id=29, name=reactive_energy, samples=['Reactive Energy Import T', 'Reactive Energy Export T']), Group(id=30, name=adc_raw, samples=['ADCRawValue', 'ADCRaw']), Group(id=31, name=adc_channel_0_V, samples=['ADC_CH0V']), Group(id=32, name=adc_raw_is_changed, samples=['ADCreadValueChange', 'ADCRawChange']), Group(id=33, name=general_alarm, samples=['Alarm', 'Alarm_status', 'ALARM', 'FaultAlarm']), Group(id=34, name=fire_alarm, samples=['FireAlarm', 'fire']), Group(id=35, na ...

# %%
# train data
x = []
y = []
for e in groups:
  x.extend(e.samples)
  # x.extend(e.key_words)
  # y.extend([e.id] * (len(e.samples) + len(e.key_words)))
  y.extend([e.id] * len(e.samples))

# %%
#get test set
f = open('adeunis--arf8123aa.json', 'r')


json_data = json.load(f)
f.close()
# a = flatten_json(json_text)
x_test = extract_paths(json_data)

# %%
print(x_test)
# Out:
# ['deduplicationId', 'time', 'deviceInfo.tenantId', 'deviceInfo.tenantName', 'deviceInfo.applicationId', 'deviceInfo.applicationName', 'deviceInfo.deviceProfileId', 'deviceInfo.deviceProfileName', 'deviceInfo.deviceName', 'deviceInfo.devEui', 'deviceInfo.deviceClassEnabled', 'devAddr', 'adr', 'dr', 'fCnt', 'fPort', 'confirmed', 'data', 'object.dl_counter', 'object.hdop', 'object.rssi_dl', 'object.temperature', 'object.gps_quality', 'object.battery_level', 'object.lati_hemisphere', 'object.ul_counter', 'object.snr_dl', 'object.sats', 'object.koterberg', 'object.longitude', 'object.payload', 'object.long_hemisphere', 'object.latitude', 'rxInfo[0].gatewayId', 'rxInfo[0].uplinkId', 'rxInfo[0].time', 'rxInfo[0].timeSinceGpsEpoch', 'rxInfo[0].fineTimeSinceGpsEpoch', 'rxInfo[0].rssi', 'rxInfo[0].snr', 'rxInfo[0].channel', 'rxInfo[0].rfChain', 'rxInfo[0].location.latitude', 'rxInfo[0].location.longitude', 'rxInfo[0].location.altitude', 'rxInfo[0].context', 'rxInfo[0].metadata.region_common_name', 'rxInfo[0].metadata.region_config_id', 'txInfo.frequency', 'txInfo.modulation.lora.bandwidth', 'txInfo.modulation.lora.spreadingFactor', 'txInfo.modulation.lora.codeRate']

# %% [markdown]
# # vectorization & rfc

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.svm import SVC


# Count vectorization for paths
vectorizer = CountVectorizer(analyzer='char', ngram_range=(3, 4))
# vectorizer = TfidfVectorizer(analyzer='char', ngram_range=(2, 5))
# vectorizer = HashingVectorizer(analyzer='char', ngram_range=(3, 5), n_features=1000)

X = vectorizer.fit_transform(x)  # sparse matrix

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# classifier = RandomForestClassifier()
classifier = SVC(kernel='linear')
# rf_classifier = RandomForestClassifier(n_estimators=100)
# rf_classifier.fit(X_train, y_train)
# rf_classifier.fit(X, y)

# y_pred = rf_classifier.predict(X_test)
# from sklearn.metrics import accuracy_score

# accuracy = accuracy_score(y_test, y_pred)
# print(accuracy)

# %%
import numpy as np

# %%
scores = cross_val_score(classifier, X, y, cv=5, verbose=2)
print("Cross-validation scores:", scores)
print("Mean cross-validation score:", np.mean(scores))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# [CV] END .................................................... total time=   0.1s
# Cross-validation scores: [0.55172414 0.56896552 0.39655172 0.51724138 0.38596491]
# Mean cross-validation score: 0.4840895341802782

# %%
# train on all available data
# from gensim.models import Word2Vec

vectorizer = CountVectorizer(analyzer='char', ngram_range=(3, 6))

X = vectorizer.fit_transform(x)  # sparse matrix

rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X, y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from gensim.models import Word2Vec
import re

delimiters = ['_', '.']
pattern = '|'.join(map(re.escape, delimiters))


result = re.split(pattern, text)
result = [word for word in result if word]

x_split = [re.split(pattern, e) for e in x]
print(x_split)
# Out:
# [['batV'], ['batt_v'], ['batt_mV'], ['bat_mV'], ['Bat_V'], ['Bat_mV'], ['batteryVoltage'], ['vbat'], ['vBat'], ['batVoltage'], ['battery_vol'], ['battVoltage'], ['Vbat'], ['BatV'], ['BAT_V'], ['batteryLevel'], ['battery_level'], ['batLevel'], ['[03] Voltage Battery/Input [V]'], ['battery_voltage_mean_24h'], ['batteryPerc'], ['battPerc'], ['battery_capacity_percentage'], ['batteryCapacity'], ['battery_health'], ['Battery'], ['Bat_status'], ['temperatures'], ['temperature'], ['temp_SOIL'], ['TEMP_SOIL'], ['air_temperature'], ['Air Temperature'], ['ambientTemp'], ['ambient_temperature'], ['Ambient_Temperature'], ['barometer_temperature'], ['temperature_head'], ['head_temperature'], ['surface_temperature'], ['tempC_DS18B20'], ['TempC_DS18B20'], ['tempC_SHT'], ['TempC_SHT'], ['TempPH'], ['TempNTU'], ['SoildTemp5TE'], ['TempLDO'], ['temp_Channel'], ['Temp_Channel'], ['Leaf_Temperature'], ['Flow_Temperature'], ['soil_temperature'], ['temperature_pt1000'], ['soil_temperature_at_depth'], ['waterTemp'], ['extThermistorTemperature'], ['TH_Sensor_Temperature'], ['bleTemp'], ['sensorTemperature'], ['mcu_temperature'], ['sensor_temperature_internal'], ['temperatureBoard'], ['onboard_temperature'], ['Lidar_temp'], ['cpu_temp'], ['cputemp'], ['TemperatureLimitHigh'], ['tempMax'], ['TempC_DS'], ['tempC_DS'], ['Ext_TempC_SHT'], ['TemperatureLimitHigh'], ['tempMax'], ['TemperatureLimitLow'], ['tempMin'], ['tempAlarmLimitHigh'], ['HighTempAlarm'], ['tempAlarmLimitLow'], ['TemperatureAlertsEnabled'], ['temperatureAlertActive'], ['tempAlarmsEnabled'], ['temperatureChanged'], ['tempHumidChanged'], ['TempChange'], ['targetTemperature'], ['leak'], ['leakage_status'], ['waterleak'], ['WaterLeak'], ['WATER_LEAK_STATUS'], ['water'], ['WATER_LEAK_TIMES'], ['WaterLeakLocation'], ['TankLeakAlarm'], ['voltage'], ['Voltage'], ['input_voltage'], ['capacitor_voltage'], ['rms_voltage'], ['voltage-transformer primary'], ['voltage-transformer secondary'], ['Volt'], ['Vol'], ['Supply_Voltage'], ['Storage_Voltage'], ['SystemVoltage'], ['AVI_V'], ['IDC_intput_mA'], ['idc_intput_mA'], ['ACI_mA'], ['current'], ['Current'], ['IDC_intput_mA'], ['idc_intput_mA'], ['ACI_mA'], ['current'], ['Current'], ['openWindow'], ['window_open'], ['window_detection'], ['Door_status'], ['door_status'], ['DOOR_OPEN_STATUS'], ['closed'], ['LAST_DOOR_OPEN_DURATION'], ['DOOR_OPEN_TIMES'], ['Active Energy Import T'], ['Reactive Energy Import T'], ['Reactive Energy Export T'], ['ADCRawValue'], ['ADCRaw'], ['ADC_CH0V'], ['ADCreadValueChange'], ['ADCRawChange'], ['Alarm'], ['Alarm_status'], ['ALARM'], ['FaultAlarm'], ['FireAlarm'], ['fire'], ['Tamper'], ['power'], ['Power'], ['powerSourcedCount'], ['powerUsedCount'], ['powerSourcedPerHour'], ['powerUsedPerHour'], ['PowerOffAlarm'], ['PowerChange'], ['factor'], ['power_sum'], ['humidity'], ['Humi'], ['Humidity'], ['air_humidity'], ['humNOW'], ['humidity_percentage'], ['ambient_humidity'], ['relative_humidity'], ['relativeHumidity'], ['RelativeHumidity'], ['Hum_SHT'], ['hum_SHT'], ['EC5SoildHumi'], ['SoildHumi5TE'], ['TH_Sensor_Humidity'], ['Ext_Hum_SHT'], ['HumidityLimitHigh'], ['humMax'], ['HumidityLimitLow'], ['humMin'], ['humidityAlarmLimitHigh'], ['humidityAlarmLimitLow'], ['humidityAlarmsEnabled'], ['HumidityAlertsEnabled'], ['humidityAlertActive'], ['humidityChanged'], ['HumiChange'], ['atmospheric_pressure'], ['ambient_pressure'], ['barometric_pressure'], ['vapor_pressure'], ['AirPressure'], ['AirPressureChange'], ['co2_concentration'], ['co2_concentration_lpf'], ['CO2_ppm'], ['eco2'], ['CO2Filtered'], ['CO2Raw'], ['pm2_5_mass_concentration'], ['pm2_5_number_concentration'], ['pm10_mass_concentration'], ['tvoc'], ['TVOC'], ['TVOC_VOC'], ['TVOC_ppb'], ['TVOC_VOCChange'], ['rssi'], ['rssi_dl'], ['Rssi'], ['RSSI'], ['Beacon_RSSI'], ['rssilimit'], ['RSSIAndSNR'], ['snr'], ['Snr'], ['SNR'], ['snr_dl'], ['Latitude'], ['latitude'], ['latitudeDeg'], ['gpsLat'], ['Lat'], ['lati_hemisphere'], ['Longitude'], ['longitude'], ['longitudeDeg'], ['gpsLon ...

# %%
# x_test_vec = vectorizer.fit(x_test)
x_test_vec = vectorizer.transform(x_test)
y_pred = rf_classifier.predict(x_test_vec)



for i in range(len(y_pred)):
  classname = [group.name for group in groups if group.id == y_pred[i]][0]
  print(f'{x_test[i]} classified as {classname}')
# Out:
# deduplicationId classified as voltage
# time classified as timestamp
# deviceInfo.tenantId classified as voltage
# deviceInfo.tenantName classified as voltage
# deviceInfo.applicationId classified as motion_detected
# deviceInfo.applicationName classified as motion_detected
# deviceInfo.deviceProfileId classified as voltage
# deviceInfo.deviceProfileName classified as voltage
# deviceInfo.deviceName classified as voltage
# deviceInfo.devEui classified as voltage
# deviceInfo.deviceClassEnabled classified as illuminance_lx
# devAddr classified as voltage
# adr classified as voltage
# dr classified as voltage
# fCnt classified as voltage
# fPort classified as voltage
# confirmed classified as fire_alarm
# data classified as voltage
# object.dl_counter classified as common_error_count
# object.hdop classified as horizontal_dilution_precision
# object.rssi_dl classified as rssi_dBm
# object.temperature classified as outdoor_temperature
# object.gps_quality classified as voltage
# object.battery_level classified as battery_voltage
# object.lati_hemisphere classified as lati_hemisphere
# object.ul_counter classified as common_error_count
# object.snr_dl classified as snr_ratio
# object.sats classified as satellites_number
# object.koterberg classified as voltage
# object.longitude classified as longitude
# object.payload classified as payload_hex
# object.long_hemisphere classified as longitude
# object.latitude classified as latitude
# rxInfo[0].gatewayId classified as illuminance_lx
# rxInfo[0].uplinkId classified as voltage
# rxInfo[0].time classified as timestamp
# rxInfo[0].timeSinceGpsEpoch classified as timestamp
# rxInfo[0].fineTimeSinceGpsEpoch classified as timestamp
# rxInfo[0].rssi classified as rssi_dBm
# rxInfo[0].snr classified as snr_ratio
# rxInfo[0].channel classified as illuminance_lx
# rxInfo[0].rfChain classified as voltage
# rxInfo[0].location.latitude classified as latitude
# rxInfo[0].location.longitude classified as longitude
# rxInfo[0].location.altitude classified as altitude
# rxInfo[0].context classified as external_sensors_exist
# rxInfo[0].metadata.region_common_name classified as voltage
# rxInfo[0].metadata.region_config_id classified as voltage
# txInfo.frequency classified as voltage
# txInfo.modulation.lora.bandwidth classified as latitude
# txInfo.modulation.lora.spreadingFactor classified as power_factor
# txInfo.modulation.lora.codeRate classified as latitude

# %%
res = {}

for i in range(len(y_pred)):
  # get the leaf

  res[]
  classname = [group.name for group in groups if group.id == y_pred[i]][0]
  print(f'{x_test[i]} classified as {classname}')
